# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdevpy/Pythonlab/blob/main/Ampliando_dataset_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Para utilizar as imagens geradas, crie uma função que as salve.

# %%
#https://keras.io/api/preprocessing/image/

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.pyplot import imread,imshow,subplots,show


def plot(data_generator):
  data_generator.fit(images)
  image_iterator=data_generator.flow(images)

  fig,rows=subplots(nrows=1,ncols=4,figsize=(18,18))

  for row in rows:
    row.imshow(image_iterator.next()[0].astype('int'))
    row.axis('off')
  show()
#importe aqui sua imagem
image=imread('/content/Pato.jpg')

images=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))

imshow(images[0])
show()

# %%
#Rotação

try:
  data_generator= ImageDataGenerator(rotation_range=90)
  plot(data_generator)
except exception as e:
  print(e)

# %%
#ruído largura
data_generator=ImageDataGenerator(width_shift_range=0.3)
plot(data_generator)

# %%
#ruído altura
data_generator=ImageDataGenerator(height_shift_range=0.3)
plot(data_generator)

# %%
#variando brilho
data_generator=ImageDataGenerator(brightness_range=(0.1,0.9))
plot(data_generator)

# %%
#distorcendo e adicionando ruído
data_generator=ImageDataGenerator(shear_range=45.0)
plot(data_generator)

# %%
data_generator=ImageDataGenerator(zoom_range=[0.5,1.5])
plot(data_generator)

# %%
#Range de canais
data_generator=ImageDataGenerator(channel_shift_range=150.0)
plot(data_generator)
